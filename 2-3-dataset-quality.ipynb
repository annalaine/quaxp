# %% [raw]
# ---
# metadata: true
# section: "Quality of an image dataset"
# goal: "Gauge and improve the quality of an image dataset."
# time: "x min"
# prerequisites: "None"
# level: "Beginner and advanced"
# ---

# %% [markdown]
# # Quality of an image dataset

# %% [markdown]
# ## Gauge

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# See page 2-3-2-augmentation
